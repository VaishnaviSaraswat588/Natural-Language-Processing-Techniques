# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text = 'The Children are running and studies are better done'

# %%
words = word_tokenize(text)
print(words)
# Out:
# ['The', 'Children', 'are', 'running', 'and', 'studies', 'are', 'better', 'done']

# %%
lemmatizer = WordNetLemmatizer()
lemmatizer_words = [lemmatizer.lemmatize(word) for word in words]

# %%
print('original words:', words)
print('Lemmatized words:', lemmatizer_words)
# Out:
# original words: ['The', 'Children', 'are', 'running', 'and', 'studies', 'are', 'better', 'done']
# Lemmatized words: ['The', 'Children', 'are', 'running', 'and', 'study', 'are', 'better', 'done']
